# %%
# !pip install nltk
# !pip install scikit-learn
# Out:
# Requirement already satisfied: nltk in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (from click->nltk) (0.4.6)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jayac\anaconda3\envs\tf39\lib\site-packages (from scikit-learn) (1.5.1)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.2 MB 7.5 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.2 MB 9.1 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.2 MB 9.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.2 MB 10.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.2 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 10.1 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn
#
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [scikit-learn]
#    ---------------------------------------- 2/2 [scikit-learn]
#
# Successfully installed scikit-learn-1.6.1 threadpoolctl-3.6.0

# %%
import nltk
from nltk.corpus import reuters

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
tfidf.fit([reuters.raw(file_id) for file_id in reuters.fileids()])
# Out:
# TfidfVectorizer()

# %%
X = tfidf.transform([reuters.raw('test/14829')])

# %%
print([X[0, tfidf.vocabulary_['year']]])
# Out:
# [0.04958728473092144]

# %%
print([X[0, tfidf.vocabulary_['following']]])
# Out:
# [0.051786764846587646]

# %%
print([X[0, tfidf.vocabulary_['provided']]])
# Out:
# [0.0]
